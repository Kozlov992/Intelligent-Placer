# %%
from Source import *

# %%
import os

# %%
REFERENCE_CONTOURS = extract_contours()

# %%
first = 2
last = 23
y_pred = np.empty(last - first, dtype=int)
y_reference = np.empty(last - first, dtype=int)

# %%
i = 0
for name in os.listdir("tests"):
    y_reference[i], y_pred[i] = analyze_pic('tests\\' + name, REFERENCE_CONTOURS, dpi_val=150)
    i += 1
# Out:
# C:\Users\kozli\Untitled Folder\Signals\Untitled Folder\my_o\Source.py:243: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(1, 2, dpi=dpi_val)

# %%
from Utils import *

# %%
display_confusion_matrix(confusion_matrix(y_true=y_reference, y_pred=y_pred), "cf_matrix.png")
