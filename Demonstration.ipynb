# %%
from Source import *

# %%
REFERENCE_CONTOURS = extract_contours()

# %% [markdown]
# ### 1. Пример работы алгоритма на простом примере:

# %%
analyze_pic('demonstration\\1_t.jpg', REFERENCE_CONTOURS)
# Out:
# (True, True)

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 2. Показательные случаи:

# %% [markdown]
# #### 1. Суммарная площадь вмещаемых объектов больше площади, ограничиваемой многоугольником:

# %%
analyze_pic('demonstration\\2_f.jpg', REFERENCE_CONTOURS)
# Out:
# (False, False)

# %% [markdown]
# <br>

# %% [markdown]
# #### 2. Диаметр вмещаемого предмета больше диаметра многоугольника:

# %%
analyze_pic('demonstration\\3_f.jpg', REFERENCE_CONTOURS)
# Out:
# (False, False)

# %% [markdown]
# <br>

# %% [markdown]
# #### 3. Краеугольный случай для алгоритма. Отчетливо заметно, что предложенные предметы можно разместить внутри многоугольника, однако из-за того, что контуры вмещаемых предметов сортируются (в обратном порядке) по ограничиваемой ими площади, круг всегда будет идти первым в очереди на вмещение и занимать позицию, ни при каких условиях не позволяющую вмещаться карандашу.

# %%
analyze_pic('demonstration\\4_t.jpg', REFERENCE_CONTOURS)
# Out:
# (True, False)

# %% [markdown]
# <br>

# %% [markdown]
# #### 4. Для размещения внутри многоугольника контур предмета должен быть повернут на некоторый угол:

# %%
analyze_pic('demonstration\\5_t.jpg', REFERENCE_CONTOURS)
# Out:
# (True, True)

# %% [markdown]
# <br>

# %% [markdown]
# #### 5. Для размещения внутри многоугольника контуры нужно плотно упаковать:

# %%
analyze_pic('demonstration\\6_t.jpg', REFERENCE_CONTOURS)
# Out:
# (True, True)

# %% [markdown]
# <br>

# %% [markdown]
# #### 6. Пример наглядно демонстрирует использование bottom-left эвристики в алгоритме:

# %%
analyze_pic('demonstration\\7_t.jpg', REFERENCE_CONTOURS)
# Out:
# (True, True)
